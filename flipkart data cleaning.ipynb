# %%
# importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
# %pip install nltk
# Out:
# ...
#
# ...

# %%
# uoloading the dataset

# %%
data=pd.read_csv("C:/Users/soora/Downloads/flipkart_com-ecommerce_sample.csv/flipkart_com-ecommerce_sample.csv")

# %%
data.head(5)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20002 entries, 0 to 20001
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  object
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
data.describe()
# Out:
#         retail_price  discounted_price
# count   19922.000000      19922.000000
# mean     2979.206104       1973.401767
# std      9009.639341       7333.586040
# min        35.000000         35.000000
# 25%       666.000000        350.000000
# 50%      1040.000000        550.000000
# 75%      1999.000000        999.000000
# max    571230.000000     571230.000000

# %%
data.isnull().sum()
# Out:
# uniq_id                       2
# crawl_timestamp               2
# product_url                   2
# product_name                  2
# product_category_tree         2
# pid                           2
# retail_price                 80
# discounted_price             80
# image                         5
# is_FK_Advantage_product       2
# description                   4
# product_rating                2
# overall_rating                2
# brand                      5866
# product_specifications       16
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# visualing the null values

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# drop unimportnt columns

# %%
data.drop(['image'],axis=1,inplace=True)

# %%
data.drop(['is_FK_Advantage_product'],axis=1,inplace=True)

# %%
data.drop(['description'],axis=1,inplace=True)

# %%
data.drop(['product_specifications'],axis=1,inplace=True)

# %%
data.drop(['pid'],axis=1,inplace=True)

# %%
data.drop(['uniq_id'],axis=1,inplace=True)

# %%
data.drop(['product_url'],axis=1,inplace=True)

# %%
data= data.dropna(subset=['product_category_tree'], axis=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   crawl_timestamp        20000 non-null  object
#  1   product_name           20000 non-null  object
#  2   product_category_tree  20000 non-null  object
#  3   retail_price           19922 non-null  float64
#  4   discounted_price       19922 non-null  float64
#  5   product_rating         20000 non-null  object
#  6   overall_rating         20000 non-null  object
#  7   brand                  14136 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 1.4+ MB

# %%
data.head(5)
# Out:
#              crawl_timestamp                           product_name  \
# 0  2016-03-25 22:59:23 +0000    Alisha Solid Women's Cycling Shorts
# 1  2016-03-25 22:59:23 +0000    FabHomeDecor Fabric Double Sofa Bed
# 2  2016-03-25 22:59:23 +0000                             AW Bellies
# 3  2016-03-25 22:59:23 +0000    Alisha Solid Women's Cycling Shorts
# 4  2016-03-25 22:59:23 +0000  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree  retail_price  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1  ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
#
#    discounted_price       product_rating       overall_rating         brand
# 0             379.0  No rating available  No rating available        Alisha
# ...

# %%
data1.head(5)
# Out:
#              crawl_timestamp                           product_name  \
# 0  2016-03-25 22:59:23 +0000    Alisha Solid Women's Cycling Shorts
# 1  2016-03-25 22:59:23 +0000    FabHomeDecor Fabric Double Sofa Bed
# 2  2016-03-25 22:59:23 +0000                             AW Bellies
# 3  2016-03-25 22:59:23 +0000    Alisha Solid Women's Cycling Shorts
# 4  2016-03-25 22:59:23 +0000  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree retail_price  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...        999.0
# 1  ["Furniture >> Living Room Furniture >> Sofa B...      32157.0
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...        999.0
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...        699.0
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...        220.0
#
#   discounted_price       product_rating       overall_rating         brand
# 0            379.0  No rating available  No rating available        Alisha
# ...

# %%
# Replace 'column_name' with the name of the column you want to check for float values
column_name = "product_category_tree"

# Drop rows with float values in the specified column
data= data.drop(data[data[column_name].apply(lambda x: isinstance(x, float))].index)

# %%
import pandas as pd
import re

# %%
# A function to Clean the product_category_tree and return Primary_Category
def clean_prod_category():
  primary_category=[]
  #iterate in col
  for ele in data['product_category_tree']: 
    ele=ele.replace('"]',"")
    category=ele[2:].split(" >>")
    primary_category.append(category[0])
  
  #returinig the clean data
  return primary_category

# %%
primary_category=clean_prod_category()

#Verfying the output
primary_category
# Out:
# ['Clothing',
#  'Furniture',
#  'Footwear',
#  'Clothing',
#  'Pet Supplies',
#  'Eternal Gandhi Super Series Crystal Paper Weight...',
#  'Clothing',
#  'Furniture',
#  'Footwear',
#  'Clothing',
#  'Footwear',
#  'Clothing',
#  'Pet Supplies',
#  'Clothing',
#  'Pens & Stationery',
#  'Clothing',
#  'Furniture',
#  'Footwear',
#  'Clothing',
#  'Furniture',
#  'Pet Supplies',
#  'Clothing',
#  'Clothing',
#  'Footwear',
#  'Pet Supplies',
#  'Clothing',
#  'Sports & Fitness',
#  'Beauty and Personal Care',
#  'Clothing',
#  'Clothing',
#  'Bengal Blooms Rose Artificial Plant  with Pot (3...',
#  'Clothing',
#  'Pens & Stationery',
#  'Pens & Stationery',
#  'Pens & Stationery',
#  'Clothing',
#  'Pens & Stationery',
#  'Clothing',
#  'Bags, Wallets & Belts',
#  'Clothing',
#  'Footwear',
#  'Home Decor & Festive Needs',
#  'Automotive',
#  'Tools & Hardware',
#  "Vishudh Printed Women's Straight Kurta",
#  "Vishudh Printed Women's Straight Kurta",
# ...

# %%
data.head(5)
# Out:
#              crawl_timestamp                           product_name  \
# 0  2016-03-25 22:59:23 +0000    Alisha Solid Women's Cycling Shorts
# 1  2016-03-25 22:59:23 +0000    FabHomeDecor Fabric Double Sofa Bed
# 2  2016-03-25 22:59:23 +0000                             AW Bellies
# 3  2016-03-25 22:59:23 +0000    Alisha Solid Women's Cycling Shorts
# 4  2016-03-25 22:59:23 +0000  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree  retail_price  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1  ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
#
#    discounted_price       product_rating       overall_rating         brand
# 0             379.0  No rating available  No rating available        Alisha
# ...

# %%
data['category']=primary_category

# %%
data.head(5)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
data.drop(['product_category_tree'],axis=1,inplace=True)

# %%
data.head(5)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name               pid  retail_price  \
# 0    Alisha Solid Women's Cycling Shorts  SRTEH2FF9KEDEFGF         999.0
# 1    FabHomeDecor Fabric Double Sofa Bed  SBEEH3QGU7MFYJFY       32157.0
# ...

# %%
flipkart_cleaned_data2=data.to_csv("C:/Users/soora/OneDrive/Desktop/flipkart/flipkart_cleaned_data2.csv")

# %%
flipkart=pd.read_csv('C:/Users/soora/OneDrive/Desktop/flipkart/flipkart_cleaned_data2.csv')
flipkart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               20000 non-null  int64
#  1   uniq_id                  20000 non-null  object
#  2   crawl_timestamp          20000 non-null  object
#  3   product_url              20000 non-null  object
#  4   product_name             20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
# filling the null values

# %%
df=flipkart.fillna('NA')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               20000 non-null  int64
#  1   uniq_id                  20000 non-null  object
#  2   crawl_timestamp          20000 non-null  object
#  3   product_url              20000 non-null  object
#  4   product_name             20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20000 non-null  object
#  7   discounted_price         20000 non-null  object
#  8   image                    20000 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              20000 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    20000 non-null  object
# ...

# %%
print(df['category'].value_counts(dropna=False))
# Out:
# category
# Clothing                                               6198
# Jewellery                                              3531
# Footwear                                               1227
# Mobiles & Accessories                                  1099
# Automotive                                             1012
#                                                        ...
# Mast & Harbour Gold Synthetic  Clutch                     1
# Asics Gel-Cumulus 17 Running Shoes                        1
# Glacier Running Shoes                                     1
# Starsy Solid Women's Round Neck Green T-Shirt             1
# Areon Luxurious Fragrance Long Lasting Car,Home,...       1
# Name: count, Length: 265, dtype: int64

# %%
specific_column = 'category' 
column_counts = df['category'].value_counts()

# %%
mask = df[specific_column].isin(column_counts[column_counts < 100].index)

# %%
df_filtered = df[~mask]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               20000 non-null  int64
#  1   uniq_id                  20000 non-null  object
#  2   crawl_timestamp          20000 non-null  object
#  3   product_url              20000 non-null  object
#  4   product_name             20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20000 non-null  object
#  7   discounted_price         20000 non-null  object
#  8   image                    20000 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              20000 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    20000 non-null  object
# ...
